# %%
name='DurgaPrasad'
print(name)
# Out:
# DurgaPrasad

# %%
Prasad=name
print(type(name))
# Out:
# <class 'str'>

# %%
name='DurgaPrasad'
age=22
salary=10.000
is_name_active=True
print(type(salary))            #To Know The DataTypes We Use Type Stmt
print(type(is_name_active))
print(type(name))
print(type(age))
print(name)
print(age)
print(salary)
print(is_name_active)
# Out:
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'int'>
# DurgaPrasad
# 22
# 10.0
# True

# %%
Student1=['Prasad',22,'Male']        #It Is Nothing But A List & We Can Modify It
Student1                             #It Gives Output In An Order
# Out:
# ['Prasad', 22, 'Male']

# %%
StudentDetails={'Prasad',22,'Male'}   #It Gives Random Output
type(StudentDetails)
studentDetails
# Out:
# {22, 'Male', 'Prasad'}

# %%
Student1=('Prasad',22,'Male')         # This Set Is Called Tuple And It Will Not Be Modified
Student1                              # In This We Cannot Add Or Delete
# Out:
# ('Prasad', 22, 'Male')

# %%
x=10
y=5
x+y
x-y
x*y
# Out:
# 50

# %%
x,y=5,9
x+=y
print(x)
x-=y
print(x)
x*=y
print(x)
y*=x
print(y)
# Out:
# 14
# 5
# 45
# 405

# %%
x=7
y=8
x!=y and x==y # one condition true another conition false then it gives false
x<y and x!=y  # if both the conditions are true then only it gives true
# Out:
# True

# %%
x=5
y=9
x<y or x>y #in this if condition gets true then it gives the value true
# Out:
# True
